# %% [markdown]
# T11=('A',)
# print(T11)
# print(type(T11))

# %% [markdown]
# T12=(45,)
# print(12)
# print(type(T12))

# %%
t2=("A","B","C","D","E")
y=list(t2)
print(type(y))
# Out:
# <class 'list'>

# %%
y
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
y[2]=11

# %%
y
# Out:
# ['A', 'B', 11, 'D', 'E']

# %%
z=list(t2)

# %%
z.append(6)

# %%
z
# Out:
# ['A', 'B', 'C', 'D', 'E', 6]

# %%
t2=tuple(z)

# %%
t2
# Out:
# ('A', 'B', 'C', 'D', 'E', 6)

# %%
tuple_add1=(7,)

# %%
tuple_add2=(5,6,8,9)

# %%
tuple_add1=tuple_add1+tuple_add2

# %%
tuple_add1
# Out:
# (7, 5, 6, 8, 9)
