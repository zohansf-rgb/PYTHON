# %%
set1={1,2,3,4,5,6,7}
print(3 in set1)
# Out:
# True

# %%
print(5 in set1)
# Out:
# True

# %%
print(8 not in set1)
# Out:
# True

# %%
set1.add(8)
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
list1=["A","B","C","D"]
set1.update(list1)
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 'A', 'B', 'C', 'D'}

# %%
set1.remove(8) 
set1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'A', 'B', 'C', 'D'}
