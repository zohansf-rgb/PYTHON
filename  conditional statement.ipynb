# %%
colour=["red","yellow","blue","green","grey"]
print(colour[0])
print(colour[1])
print(colour[2])
print(colour[3])
print(colour[4])
# Out:
# red
# yellow
# blue
# green
# grey

# %%
list=[50,60,70,80]
list[0]=55
print(list)
# Out:
# [55, 60, 70, 80]

# %%
x=5
y=10
print(x==y)
# Out:
# False

# %%
x=5
y=10
print(x<y)
# Out:
# True

# %%
x=20

y=40
x>20 and y<40
# Out:
# False

# %%
a=45
a+=67
a
# Out:
# 112

# %%
a=15
b=20
a>b or a<b
# Out:
# True

# %%
person={"name":"zohan","age":24}
print(person["age"])
# Out:
# 24

# %%
person={"name":"zohan","age":24}
print(person)
# Out:
# {'name': 'zohan', 'age': 24}

# %%
age=20
if age >=18:
    print("eligiable")
# Out:
# eligiable

# %%
marks=80
if marks>=35:
    print(marks)
# Out:
# 80

# %%
num=12
if num % 2==0:
    print("even")
else:
  print("odd")
# Out:
# even

# %%
a,b,c = 12,25,9
if a>b and a>c:
    print("a is greatest")
elif b>c:
    print("b is greatest")
else:
    print("c is greatest")
# Out:
# b is greatest

# %%
x =90
if 100>=x>=90:
    print("a grade")
elif 90>x>=80:
    print("b grade")
elif 80>x>=70:
    print("c grade")
elif 70>x>=60:
    print("d grade")
else :
    print("f grade")
# Out:
# a grade

# %%
age = 20
if age>=18:
    print("you are eligible to vote")
else:
    print("can't vote")
# Out:
# you are eligible to vote

# %%
x =int(input("enter a number of choice:"))
if 100>=x>=90:
    print("a grade")
elif 90>x>=80:
    print("b grade")
elif 80>x>=70:
    print("c grade")
elif 70>x>=60:
    print("d grade")
else :
    print("f grade")

# %%
num=12
if num % 2==0:
    print("even")
else:
  print("odd")

# %%
x=int(input("a no of your choice"))
if x>0:
    print("positive")
else:
    print("negetive")
# Out:
# a no of your choice 74
# positive

# %%
x=int(input("a no of your choice for x"))
y=int(input("a no of your choice for y"))
z=int(input("a no of your choice for z"))
if x>y and x>z:
    print("x is gratest")
elif y>x and y>z:
    print("y is gratest")
else:
     print("z is gratest")
# Out:
# a no of your choice for x 85
# a no of your choice for y 83
# a no of your choice for z 45
# x is gratest

# %%
z=2
while z<40:
    print(z)
    z+=2
