# %%
x=50
y=80
print(x+y)
print(x-y)
print(x/y)
print(x//y)
# Out:
# 130
# -30
# 0.625
# 0

# %%
car=['GTR','SUPRA','KONISEG']
print(car)
# Out:
# ['GTR', 'SUPRA', 'KONISEG']

# %%
stu=["garvit","zohan","keshav","madhurima"]
print(stu[3])
print(stu[5:])
print(stu[:3])
print(stu[-4:-1])
stu.append("ayushi")
print(stu)
stu.insert(7,"vikas")
print(stu)
student=["sakshi"]
stu.extend(student)
print(stu)
stu.remove("vikas")
print(stu)
stu.pop()
del stu [9]
print(stu)
Qstu.copy()
print(Q)
stu.clear()
print(stu)
# Out:
# madhurima
# []
# ['garvit', 'zohan', 'keshav']
# ['garvit', 'zohan', 'keshav']
# ['garvit', 'zohan', 'keshav', 'madhurima', 'ayushi']
# ['garvit', 'zohan', 'keshav', 'madhurima', 'ayushi', 'vikas']
# ['garvit', 'zohan', 'keshav', 'madhurima', 'ayushi', 'vikas', 'sakshi']
# ['garvit', 'zohan', 'keshav', 'madhurima', 'ayushi', 'sakshi']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 16
#      14 print(stu)
#      15 stu.pop()
# ---> 16 del stu [9]
#      17 print(stu)
#      18 Qstu.copy()
#
# IndexError: list assignment index out of range
