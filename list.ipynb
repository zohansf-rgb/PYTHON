# %%
#list creation
L1=[1,2,3,4,5]
print(L1)
# Out:
# [1, 2, 3, 4, 5]

# %%
#list type
print(type(L1))
# Out:
# <class 'list'>

# %%
L2=["class",2,3,4,True,False]
print(L2)
# Out:
# ['class', 2, 3, 4, True, False]

# %%
print(type(L2))
# Out:
# <class 'list'>

# %%
print(len(L2))
# Out:
# 6

# %%
L3=["a","b","c","a","c"]

# %%
print(L3)
# Out:
# ['a', 'b', 'c', 'a', 'c']

# %%
L3[1]
# Out:
# 'b'

# %%
L3[4]
# Out:
# 'c'

# %%
L3[2:4]
# Out:
# ['c', 'a']

# %%
L3[0:3]
# Out:
# ['a', 'b', 'c']

# %%
L3[0:5]
# Out:
# ['a', 'b', 'c', 'a', 'c']

# %%
L3[:5]
# Out:
# ['a', 'b', 'c', 'a', 'c']

# %%
L3[2:5]
# Out:
# ['c', 'a', 'c']

# %%
L3[2:]
# Out:
# ['c', 'a', 'c']

# %%
L3[3:]
# Out:
# ['a', 'c']

# %%
L4=["a","b","c","d","e"]

# %%
L4[-4:-1]
# Out:
# ['b', 'c', 'd']

# %%
L4[-5:]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
L4[-2:]
# Out:
# ['d', 'e']

# %%
#change items
L5=[12,34,65,89,23]
print(L5)
# Out:
# [12, 34, 65, 89, 23]

# %%
L5[3]=45778
print(L5)
# Out:
# [12, 34, 65, 45778, 23]

# %%
L6=["A","B","C","D","E"]
print(L6)
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
L6[2]=456
print(L6)
# Out:
# ['A', 'B', 456, 'D', 'E']

# %%
L7=[541345,34654,3,532678,8474,3257,47756,165678,5473255,346867,745]
L7[8]=455767856346579678
print(L7)
# Out:
# [541345, 34654, 3, 532678, 8474, 3257, 47756, 165678, 455767856346579678, 346867, 745]

# %%
L7[-9]=87654321
print(L7)
# Out:
# [541345, 34654, 87654321, 532678, 8474, 3257, 47756, 165678, 455767856346579678, 346867, 745]

# %%
L7[1:3]=776543,34567
print(L7)
# Out:
# [541345, 776543, 34567, 532678, 8474, 3257, 47756, 165678, 455767856346579678, 346867, 745]

# %%
sports=["cricket","baseball","volliball","basketball","golf"]
print(sports)
print(sports[0])
print(sports[1])
print(sports[2])
print(sports[3])
print(sports[4])
print(sports[2:])
print(sports[:5])
print(sports[1:4])
sports[2]="badminton"
print(sports)
# Out:
# ['cricket', 'baseball', 'volliball', 'basketball', 'golf']
# cricket
# baseball
# volliball
# basketball
# golf
# ['volliball', 'basketball', 'golf']
# ['cricket', 'baseball', 'volliball', 'basketball', 'golf']
# ['baseball', 'volliball', 'basketball']
# ['cricket', 'baseball', 'badminton', 'basketball', 'golf']

# %%
#append items
lang=["c++","java","python","R"]
print(lang)
# Out:
# ['c++', 'java', 'python', 'R']

# %%
lang.append("excel")
print(lang)
# Out:
# ['c++', 'java', 'python', 'R', 'excel']

# %%
lang.insert(2,"xcvb")
print(lang)
# Out:
# ['c++', 'java', 'xcvb', 'xcvb', 'python', 'R', 'excel', 'B.sc', 'B|', 'B|', 'B|', 'm.sc', 'diploma', 'B|']

# %%
course=["B.sc","m.sc","diploma"]
print(course)
# Out:
# ['B.sc', 'm.sc', 'diploma']

# %%
lang.extend(course)
print(lang)
# Out:
# ['c++', 'java', 'python', 'R', 'excel', 'B.sc', 'B|', 'B|', 'B|', 'm.sc', 'diploma', 'B|']

# %%
list22=["Keshav","garvit","Salman","Amir","Sakshi"]
list22.remove("Sakshi")
print(list22)
# Out:
# ['Keshav', 'garvit', 'Salman', 'Amir']

# %%
list22.pop()
print(list22)
# Out:
# ['Keshav', 'garvit', 'Salman']

# %%
list22=["Keshav","garvit","Salman","Amir","Sakshi"]
list22.pop()
print(list22)
# Out:
# ['Keshav', 'garvit', 'Salman', 'Amir']

# %%
list45=[123,6543,3456787,6545678,987645678,98]
del list45[4]
print(list45)
# Out:
# [123, 6543, 3456787, 6545678, 98]

# %%
del list45
print(list45)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 del list45
# ----> 2 print(list45)
#
# NameError: name 'list45' is not defined

# %%
list67=["ddlj","bagh","john"]
list67.clear()
print(list67)
# Out:
# []

# %%
G=["sdsdf","sdfg","sdfgh","sdfgh""werty","qwerty"]
print(G)
# Out:
# ['sdsdf', 'sdfg', 'sdfgh', 'sdfghwerty', 'qwerty']

# %%
A=G.copy()

# %%
print(A)
# Out:
# ['sdsdf', 'sdfg', 'sdfgh', 'sdfghwerty', 'qwerty']

# %%
L11=list(A)
print(L11)
# Out:
# ['sdsdf', 'sdfg', 'sdfgh', 'sdfghwerty', 'qwerty']

# %%
F=L11+A
print(F)
# Out:
# ['sdsdf', 'sdfg', 'sdfgh', 'sdfghwerty', 'qwerty', 'sdsdf', 'sdfg', 'sdfgh', 'sdfghwerty', 'qwerty']

# %%
L88=[987654,12345678,123456780,23456789,9876543,2345678,9876543,23456789,987654322,34567890,9876543223456]
print(min(L88))
print(max(L88))
# Out:
# 987654
# 9876543223456

# %%
stu=["Keshav","Ayushi","Sakshi","Amir","Salman","Garvit","Rahul","Abhishek","Sanskar","Zohan"]
print(stu[3])
print(stu[5:])
print(stu[:3])
print(stu[-4:-1])
stu.append("Aadesh")
print(stu)
stu.insert(7,"Vikas")
print(stu)
Student=["Madhurima"]
stu.extend(Student)
print(stu)
stu.remove("Vikas")
print(stu)
stu.pop()
print(stu)
del stu[9]
print(stu)
Q=stu.copy()
print(Q)
stu.clear()
print(stu)
# Out:
# Amir
# ['Garvit', 'Rahul', 'Abhishek', 'Sanskar', 'Zohan']
# ['Keshav', 'Ayushi', 'Sakshi']
# ['Rahul', 'Abhishek', 'Sanskar']
# ['Keshav', 'Ayushi', 'Sakshi', 'Amir', 'Salman', 'Garvit', 'Rahul', 'Abhishek', 'Sanskar', 'Zohan', 'Aadesh']
# ['Keshav', 'Ayushi', 'Sakshi', 'Amir', 'Salman', 'Garvit', 'Rahul', 'Vikas', 'Abhishek', 'Sanskar', 'Zohan', 'Aadesh']
# ['Keshav', 'Ayushi', 'Sakshi', 'Amir', 'Salman', 'Garvit', 'Rahul', 'Vikas', 'Abhishek', 'Sanskar', 'Zohan', 'Aadesh', 'Madhurima']
# ['Keshav', 'Ayushi', 'Sakshi', 'Amir', 'Salman', 'Garvit', 'Rahul', 'Abhishek', 'Sanskar', 'Zohan', 'Aadesh', 'Madhurima']
# ['Keshav', 'Ayushi', 'Sakshi', 'Amir', 'Salman', 'Garvit', 'Rahul', 'Abhishek', 'Sanskar', 'Zohan', 'Aadesh']
# ['Keshav', 'Ayushi', 'Sakshi', 'Amir', 'Salman', 'Garvit', 'Rahul', 'Abhishek', 'Sanskar', 'Aadesh']
# ['Keshav', 'Ayushi', 'Sakshi', 'Amir', 'Salman', 'Garvit', 'Rahul', 'Abhishek', 'Sanskar', 'Aadesh']
# []
